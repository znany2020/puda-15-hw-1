# %% [markdown]
# Решение задания 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Решение задания 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Решение 3

# %% [markdown]
# https://github.com/znany2020/puda-15-hw-1 - ссылка на репозитарий
